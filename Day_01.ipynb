# %% [markdown]
# <a href="https://colab.research.google.com/github/MLWithNithya/debugging_mylife_with_python/blob/main/Day_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.Syntax and Semantics
# - Syntax = structure / grammar of code
#
# - It defines how code must be written so the interpreter/compiler can parse it.
#
# ## Semantics
#
# - Semantics = meaning / behavior of code
#
# - It defines what the code actually does when it runs.

# %% [markdown]
# # 2.Case sensitivity
#
# capital letters and small letters are treated as unique characters in python

# %% [markdown]
# # 3.Indentation
#
# - It indicates the block of code or the code under its scope.
#
# - Any statement ending with : must be followed by an indented block:
